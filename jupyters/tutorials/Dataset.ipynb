# %%
from data import PlantNet300K
val_dataset = PlantNet300K(root="/home/files/datasets/plantnet_300K/", split="val")
class_to_name = val_dataset.class_to_name
item = val_dataset.__getitem__(0)
image, _class = item
print(image.shape, _class)
from matplotlib import pyplot as plt

plt.title(class_to_name[_class])
plt.imshow(image)
plt.show()
# Out:
# (600, 600, 3) 779
